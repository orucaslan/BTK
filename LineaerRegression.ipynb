# %% [markdown]
# <a href="https://colab.research.google.com/github/orucaslan/BTK/blob/main/LineaerRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Prediction Linear Regression

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-dbe8c1d2-cc7b-4055-a830-e8b6eea3a463" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dbe8c1d2-cc7b-4055-a830-e8b6eea3a463">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("satislar.csv")

# %%
df
# Out:
#     Aylar  Satislar
# 0       8   19671.5
# 1      10   23102.5
# 2      11   18865.5
# 3      13   21762.5
# 4      14   19945.5
# 5      19   28321.0
# 6      19   30075.0
# 7      20   27222.5
# 8      20   32222.5
# 9      24   28594.5
# 10     25   31609.0
# 11     25   27897.0
# 12     25   28478.5
# 13     26   28540.5
# 14     29   30555.5
# 15     31   33969.0
# 16     32   33014.5
# 17     34   41544.0
# 18     37   40681.5
# 19     37   46970.0
# 20     42   45869.0
# 21     44   49136.5
# 22     49   50651.0
# 23     50   56906.0
# 24     54   54715.5
# 25     55   52791.0
# 26     59   58484.5
# 27     59   56317.5
# 28     64   61195.5
# 29     65   60936.0

# %%
import matplotlib.pyplot as plt

plt.scatter(df.Aylar, df.Satislar)
plt.show()

# %%
X = df[["Aylar"]]

# %%
y = df[["Satislar"]]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %%
X_train
# Out:
#     Aylar
# 5      19
# 16     32
# 8      20
# 14     29
# 23     50
# 20     42
# 1      10
# 29     65
# 6      19
# 4      14
# 18     37
# 19     37
# 9      24
# 7      20
# 25     55
# 3      13
# 0       8
# 21     44
# 15     31
# 12     25

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
# X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
#     Aylar
# 5      19
# 16     32
# 8      20
# 14     29
# 23     50
# 20     42
# 1      10
# 29     65
# 6      19
# 4      14
# 18     37
# 19     37
# 9      24
# 7      20
# 25     55
# 3      13
# 0       8
# 21     44
# 15     31
# 12     25

# %%
#X_test = scaler.fit_transform(X_test)

# %%
#y_train = scaler.fit_transform(y_train)

# %%
#y_test = scaler.fit_transform(y_test)

# %% [markdown]
# # Model Oluşturma

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test)
# Out:
# array([[20991.93663769],
#        [62142.93172873],
#        [32638.44468232],
#        [31862.01081268],
#        [58260.76238052],
#        [54378.59303231],
#        [58260.76238052],
#        [31862.01081268],
#        [38849.91563946],
#        [50496.4236841 ]])

# %%
y_test
# Out:
#     Satislar
# 2    18865.5
# 28   61195.5
# 13   28540.5
# 10   31609.0
# 26   58484.5
# 24   54715.5
# 27   56317.5
# 11   27897.0
# 17   41544.0
# 22   50651.0

# %%
X_test = X_test.sort_index()

# %%
y_test = y_test.sort_index()

# %%
plt.plot(X_test, y_test)
plt.plot(X_test, lr.predict(X_test))
