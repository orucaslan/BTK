# %%
import pandas as pd 
import numpy as np

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-89b629c0-6b25-4ffd-a317-354117de9bc3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-89b629c0-6b25-4ffd-a317-354117de9bc3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
hamVeri = pd.read_csv("eksikveriler.csv")

# %%
hamVeri
# Out:
#    ulke    boy  kilo   yas cinsiyet
# 0    tr  130.0    30  10.0        e
# 1    tr  125.0    36  11.0        e
# 2    tr  135.0    34  10.0        k
# 3    tr  133.0    30   9.0        k
# 4    tr    NaN    38  12.0        e
# 5    tr  180.0    90  30.0        e
# 6    tr  190.0    80  25.0        e
# 7    tr  175.0    90  35.0        e
# 8    tr  177.0    60  22.0        k
# 9    us  185.0   105  33.0        e
# 10   us  165.0    55  27.0        k
# 11   us  155.0    50  44.0        k
# 12   us  160.0    58   NaN        k
# 13   us  162.0    59  41.0        k
# 14   us  167.0    62  55.0        k
# 15   fr  174.0    70  47.0        e
# 16   fr  193.0    90   NaN        e
# 17   fr  187.0    80  27.0        e
# 18   fr  183.0    88  28.0        e
# 19   fr  159.0    40  29.0        k
# 20  NaN  164.0    66  32.0        k
# 21   fr  166.0    56  42.0        k

# %%
hamVeri.fillna({"yas": hamVeri["yas"].mean()}, inplace=True)

# %%
hamVeri
# Out:
#    ulke    boy  kilo    yas cinsiyet
# 0    tr  130.0    30  10.00        e
# 1    tr  125.0    36  11.00        e
# 2    tr  135.0    34  10.00        k
# 3    tr  133.0    30   9.00        k
# 4    tr    NaN    38  12.00        e
# 5    tr  180.0    90  30.00        e
# 6    tr  190.0    80  25.00        e
# 7    tr  175.0    90  35.00        e
# 8    tr  177.0    60  22.00        k
# 9    us  185.0   105  33.00        e
# 10   us  165.0    55  27.00        k
# 11   us  155.0    50  44.00        k
# 12   us  160.0    58  28.45        k
# 13   us  162.0    59  41.00        k
# 14   us  167.0    62  55.00        k
# 15   fr  174.0    70  47.00        e
# 16   fr  193.0    90  28.45        e
# 17   fr  187.0    80  27.00        e
# 18   fr  183.0    88  28.00        e
# 19   fr  159.0    40  29.00        k
# 20  NaN  164.0    66  32.00        k
# 21   fr  166.0    56  42.00        k

# %%
hamVeri.dropna(inplace=True)

# %%
hamVeri
# Out:
#    ulke    boy  kilo    yas cinsiyet
# 0    tr  130.0    30  10.00        e
# 1    tr  125.0    36  11.00        e
# 2    tr  135.0    34  10.00        k
# 3    tr  133.0    30   9.00        k
# 5    tr  180.0    90  30.00        e
# 6    tr  190.0    80  25.00        e
# 7    tr  175.0    90  35.00        e
# 8    tr  177.0    60  22.00        k
# 9    us  185.0   105  33.00        e
# 10   us  165.0    55  27.00        k
# 11   us  155.0    50  44.00        k
# 12   us  160.0    58  28.45        k
# 13   us  162.0    59  41.00        k
# 14   us  167.0    62  55.00        k
# 15   fr  174.0    70  47.00        e
# 16   fr  193.0    90  28.45        e
# 17   fr  187.0    80  27.00        e
# 18   fr  183.0    88  28.00        e
# 19   fr  159.0    40  29.00        k
# 21   fr  166.0    56  42.00        k

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder()

# %%
ulke_encoded = pd.get_dummies(hamVeri["ulke"])

# %%
ulke_encoded
# Out:
#     fr  tr  us
# 0    0   1   0
# 1    0   1   0
# 2    0   1   0
# 3    0   1   0
# 5    0   1   0
# 6    0   1   0
# 7    0   1   0
# 8    0   1   0
# 9    0   0   1
# 10   0   0   1
# 11   0   0   1
# 12   0   0   1
# 13   0   0   1
# 14   0   0   1
# 15   1   0   0
# 16   1   0   0
# 17   1   0   0
# 18   1   0   0
# 19   1   0   0
# 21   1   0   0

# %%
del hamVeri["ulke"]

# %%
hamVeri
# Out:
#       boy  kilo    yas cinsiyet
# 0   130.0    30  10.00        e
# 1   125.0    36  11.00        e
# 2   135.0    34  10.00        k
# 3   133.0    30   9.00        k
# 5   180.0    90  30.00        e
# 6   190.0    80  25.00        e
# 7   175.0    90  35.00        e
# 8   177.0    60  22.00        k
# 9   185.0   105  33.00        e
# 10  165.0    55  27.00        k
# 11  155.0    50  44.00        k
# 12  160.0    58  28.45        k
# 13  162.0    59  41.00        k
# 14  167.0    62  55.00        k
# 15  174.0    70  47.00        e
# 16  193.0    90  28.45        e
# 17  187.0    80  27.00        e
# 18  183.0    88  28.00        e
# 19  159.0    40  29.00        k
# 21  166.0    56  42.00        k

# %%
veri = pd.concat([ulke_encoded, hamVeri], axis = 1)

# %%
veri
# Out:
#     fr  tr  us    boy  kilo    yas cinsiyet
# 0    0   1   0  130.0    30  10.00        e
# 1    0   1   0  125.0    36  11.00        e
# 2    0   1   0  135.0    34  10.00        k
# 3    0   1   0  133.0    30   9.00        k
# 5    0   1   0  180.0    90  30.00        e
# 6    0   1   0  190.0    80  25.00        e
# 7    0   1   0  175.0    90  35.00        e
# 8    0   1   0  177.0    60  22.00        k
# 9    0   0   1  185.0   105  33.00        e
# 10   0   0   1  165.0    55  27.00        k
# 11   0   0   1  155.0    50  44.00        k
# 12   0   0   1  160.0    58  28.45        k
# 13   0   0   1  162.0    59  41.00        k
# 14   0   0   1  167.0    62  55.00        k
# 15   1   0   0  174.0    70  47.00        e
# 16   1   0   0  193.0    90  28.45        e
# 17   1   0   0  187.0    80  27.00        e
# 18   1   0   0  183.0    88  28.00        e
# 19   1   0   0  159.0    40  29.00        k
# 21   1   0   0  166.0    56  42.00        k

# %%
veri.to_csv("veri.csv", index=False)

# %%
veri = pd.read_csv("veri.csv")

# %%
veri
# Out:
#     fr  tr  us    boy  kilo    yas cinsiyet
# 0    0   1   0  130.0    30  10.00        e
# 1    0   1   0  125.0    36  11.00        e
# 2    0   1   0  135.0    34  10.00        k
# 3    0   1   0  133.0    30   9.00        k
# 4    0   1   0  180.0    90  30.00        e
# 5    0   1   0  190.0    80  25.00        e
# 6    0   1   0  175.0    90  35.00        e
# 7    0   1   0  177.0    60  22.00        k
# 8    0   0   1  185.0   105  33.00        e
# 9    0   0   1  165.0    55  27.00        k
# 10   0   0   1  155.0    50  44.00        k
# 11   0   0   1  160.0    58  28.45        k
# 12   0   0   1  162.0    59  41.00        k
# 13   0   0   1  167.0    62  55.00        k
# 14   1   0   0  174.0    70  47.00        e
# 15   1   0   0  193.0    90  28.45        e
# 16   1   0   0  187.0    80  27.00        e
# 17   1   0   0  183.0    88  28.00        e
# 18   1   0   0  159.0    40  29.00        k
# 19   1   0   0  166.0    56  42.00        k

# %%
from sklearn.model_selection import train_test_split

# %%
X = veri.drop(["cinsiyet"], axis=1)

# %%
y = veri["cinsiyet"]

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y, test_size=0.33 , random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.fit_transform(X_test)
